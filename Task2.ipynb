# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 1. Load the data
df = pd.read_csv('mall_customers.csv')

# 2. Select Features: Annual Income (col 3) and Spending Score (col 4)
# We use .values to convert it into a format the AI understands
X = df.iloc[:, [3, 4]].values

# 3. Create the K-Means Model
# We are asking the AI to find 3 groups (clusters)
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)

# 4. Visualizing the Clusters
plt.figure(figsize=(8,5))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1 (Low Spend)')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2 (High Spend)')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3 (Average)')

# Plotting the Centroids (The "center" of each group)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')

plt.title('Customer Groups (K-Means Clustering)')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

print("Clustering Complete. The yellow dots represent the center of each customer segment.")
# Out:
# Clustering Complete. The yellow dots represent the center of each customer segment.
